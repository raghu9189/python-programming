# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Let's load our data

# %%
df = pd.read_excel('data.xlsx')

# %%
df['Department'].value_counts()
# Out:
# Department
# Business Development        9
# Accounting                  8
# Sales                       6
# Human Resources             5
# Legal                       4
# Research and Development    4
# Services                    4
# Training                    3
# ???                         3
# Support                     3
# Marketing                   3
# Product Management          3
# Engineering                 2
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57 entries, 0 to 56
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Emp ID         57 non-null     object
#  1   Name           57 non-null     object
#  2   Gender         56 non-null     object
#  3   Department     57 non-null     object
#  4   Salary         57 non-null     float64
#  5   Start Date     57 non-null     datetime64[ns]
#  6   FTE            57 non-null     float64
#  7   Employee type  57 non-null     object
#  8   Work location  57 non-null     object
# dtypes: datetime64[ns](1), float64(2), object(6)
# memory usage: 4.1+ KB

# %%
df['SalaryDoubled'] = df['Salary'] * 2
df[['Emp ID', 'Name', 'Salary', 'SalaryDoubled']].head()
# Out:
#     Emp ID               Name     Salary  SalaryDoubled
# 0  PR00007  Torrance  Collier   96135.75      192271.50
# 1  PR00770     Beryl Burnsyde   29774.76       59549.52
# 2  PR00113        Van Tuxwell   80695.74      161391.48
# 3  PR00113        Van Tuxwell   80695.74      161391.48
# 4  PR00147   Minerva Ricardot  120000.00      240000.00
